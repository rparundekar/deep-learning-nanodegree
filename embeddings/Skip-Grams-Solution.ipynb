# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:12, 2.49MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = float(len(int_words))
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6631 0.1823 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5995 0.0800 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5123 0.0799 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6203 0.0796 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4929 0.0793 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5417 0.0799 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5755 0.0794 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5420 0.0795 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4708 0.0803 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3896 0.0804 sec/batch
# Nearest to his: maxima, suspense, dic, fingerpicking, spacesuit, poetica, remini, ponde,
# Nearest to when: negotiations, cluster, vocalizations, stint, hawks, glendale, denotation, molyneux,
# Nearest to two: rationals, roll, mulberry, subsidies, beringer, required, exterminated, bongo,
# Nearest to s: fought, dyce, monza, cie, mocking, intermediary, obeying, info,
# Nearest to would: functionalism, franc, uachtar, hedeby, hydrozoa, garten, chivalry, ancestors,
# Nearest to years: tay, intentionalists, franchisees, bak, rallies, lanarkshire, seconda, football,
# Nearest to often: kiang, isc, firmus, katie, linking, grantham, contest, indepth,
# Nearest to during: merchant, dosing, inspection, sys, erroneously, vendetta, mordor, kantele,
# Nearest to prince: prawns, acknowledged, alerting, cover, mirror, clemente, orig, nx,
# Nearest to mainly: wireless, mellaart, trebizond, constrain, sobolev, accumulator, klaipeda, hamon,
# Nearest to universe: cosmography, defenders, snack, blowing, disdainful, metafont, witty, nixon,
# Nearest to heavy: organizes, abingdon, palomar, gunmen, phosphine, moreau, worsen, monopolies,
# Nearest to active: detours, xvi, pulmonary, framework, micas, chrominance, substitutes, veered,
# Nearest to institute: samosata, onset, nl, marlboro, anders, boz, ramesses, searle,
# Nearest to bible: infliction, tyrell, byrds, num, eject, epsilon, them, formalist,
# Nearest to shows: syme, postdoctoral, atrice, cancelling, pompidou, israelite, hegemonic, nomological,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4782 0.0821 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3811 0.0799 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3276 0.0804 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2365 0.0804 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2053 0.0809 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1636 0.0816 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1203 0.0806 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0603 0.0806 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0090 0.0804 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9924 0.0813 sec/batch
# Nearest to his: suspense, maxima, year, still, landscape, victoria, fleetwood, fingerpicking,
# Nearest to when: negotiations, cluster, k, vocalizations, stint, varies, disputed, hawks,
# Nearest to two: required, roll, rationals, subsidies, famed, exterminated, position, due,
# Nearest to s: fought, cie, intermediary, info, acted, replaced, resurrected, obeying,
# Nearest to would: functionalism, franc, issues, ancestors, labelled, uachtar, affluent, chivalry,
# Nearest to years: tay, bak, football, intentionalists, older, numbering, franchisees, characteristic,
# Nearest to often: isc, linking, contest, kiang, plotinus, katie, grade, indepth,
# Nearest to during: merchant, inspection, vendetta, dosing, perform, formally, erroneously, heading,
# Nearest to prince: cover, acknowledged, mirror, prawns, trend, alerting, course, clemente,
# Nearest to mainly: wireless, mellaart, trebizond, drinkordie, calculating, trains, queen, itself,
# Nearest to universe: cosmography, defenders, since, nixon, fft, witty, metafont, carson,
# Nearest to heavy: organizes, abingdon, she, gunmen, regardless, debated, suggests, respective,
# Nearest to active: xvi, framework, detours, veered, substitutes, pulmonary, ka, lcd,
# Nearest to institute: samosata, onset, marlboro, nl, zero, boz, archaeological, ramesses,
# Nearest to bible: them, infliction, himself, byrds, formalist, while, lust, epsilon,
# Nearest to shows: syme, existed, cancelling, postdoctoral, equals, kennedy, attributes, israelite,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9370 0.0822 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9032 0.0813 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8895 0.0815 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8792 0.0820 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8097 0.0810 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8119 0.0818 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8071 0.0817 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7830 0.0809 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7929 0.0812 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7777 0.0810 sec/batch
# Nearest to his: suspense, maxima, victoria, year, tuberculosis, fingerpicking, sight, prelude,
# Nearest to when: negotiations, cluster, hawks, vocalizations, determine, glendale, stint, ephemeral,
# Nearest to two: subsidies, roll, rationals, typifies, famed, flip, electronically, formalisms,
# Nearest to s: fought, mocking, intermediary, info, monza, albrecht, cie, acted,
# Nearest to would: ancestors, functionalism, franc, uachtar, labelled, explorer, facets, issues,
# Nearest to years: tay, bak, gregorian, intentionalists, football, franchisees, older, wins,
# Nearest to often: linking, isc, contest, icon, katie, spies, kiang, grade,
# Nearest to during: merchant, erroneously, dosing, inspection, vendetta, fallacies, formally, mordor,
# Nearest to prince: cover, acknowledged, mirror, impetus, trend, bush, executive, orig,
# Nearest to mainly: wireless, mellaart, trebizond, trains, calculating, kingdom, drinkordie, occult,
# Nearest to universe: cosmography, blowing, witty, nixon, byrne, quantify, fft, sailor,
# Nearest to heavy: organizes, abingdon, monopolies, palomar, she, gunmen, politburo, hesse,
# Nearest to active: framework, xvi, detours, arriving, truman, supported, tales, veered,
# Nearest to institute: zero, samosata, onset, marlboro, nl, archaeological, boz, tennessee,
# Nearest to bible: infliction, them, himself, peasant, byrds, omits, lust, formalist,
# Nearest to shows: syme, equals, existed, kennedy, postdoctoral, cancelling, israelite, atrice,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7764 0.0821 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7409 0.0821 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7342 0.0811 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7084 0.0808 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7619 0.0822 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6976 0.0821 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7011 0.0808 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7394 0.0814 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6974 0.0809 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6485 0.0808 sec/batch
# Nearest to his: suspense, maxima, year, sight, fingerpicking, tuberculosis, victoria, lucien,
# Nearest to when: negotiations, glendale, hawks, stint, ephemeral, citizenship, tricked, denotation,
# Nearest to two: dunn, nine, zero, roll, six, subsidies, city, volkswagen,
# Nearest to s: mocking, albrecht, fought, payoffs, intermediary, info, bridgetown, monza,
# Nearest to would: functionalism, ancestors, uachtar, franc, agrarian, facets, hydrozoa, labelled,
# Nearest to years: tay, bak, gregorian, wins, rallies, football, franchisees, older,
# Nearest to often: isc, linking, contest, katie, kiang, mortar, icon, bearings,
# Nearest to during: merchant, erroneously, dosing, vendetta, inspection, liberalize, legalized, mordor,
# Nearest to prince: cover, clemente, acknowledged, bush, impetus, executive, orig, prawns,
# Nearest to mainly: wireless, mellaart, trebizond, constrain, klaipeda, kingdom, accumulator, occult,
# Nearest to universe: cosmography, blowing, witty, quantify, nixon, aqua, norwegians, byrne,
# Nearest to heavy: organizes, palomar, monopolies, abingdon, politburo, getter, gunmen, moreau,
# Nearest to active: framework, detours, xvi, arriving, truman, veered, pulmonary, micas,
# Nearest to institute: zero, samosata, nl, onset, marlboro, tennessee, archaeological, hearsay,
# Nearest to bible: infliction, them, eject, num, omits, himself, peasant, tyrell,
# Nearest to shows: syme, postdoctoral, equals, cancelling, nagel, conspicuous, kennedy, atrice,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6908 0.0819 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6707 0.0813 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6159 0.0814 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6281 0.0812 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6425 0.0813 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6274 0.0808 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6073 0.0585 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5788 0.0810 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5291 0.0813 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5203 0.0814 sec/batch
# Nearest to his: suspense, maxima, year, fingerpicking, archon, appalling, tuberculosis, sight,
# Nearest to when: negotiations, glendale, hawks, tricked, ephemeral, crossbar, narn, crevasse,
# Nearest to two: zero, six, nine, dunn, b, three, painter, seven,
# Nearest to s: mocking, info, intermediary, dyce, delta, albrecht, uprooted, fought,
# Nearest to would: ancestors, functionalism, uachtar, hydrozoa, compensate, courted, franc, hetfield,
# Nearest to years: tay, bak, gregorian, gates, rallies, total, births, older,
# Nearest to often: linking, isc, mortar, katie, kiang, atomic, franchised, contest,
# Nearest to during: merchant, erroneously, dosing, vendetta, liberalize, inspection, resounding, colonists,
# Nearest to prince: clemente, physicist, grandson, seven, cover, prawns, bush, executive,
# Nearest to mainly: wireless, mellaart, trebizond, constrain, klaipeda, abandonment, accumulator, drinkordie,
# Nearest to universe: cosmography, blowing, witty, mehr, imparts, disdainful, quantify, sultana,
# Nearest to heavy: organizes, palomar, monopolies, getter, abingdon, politburo, suggests, moreau,
# Nearest to active: detours, framework, xvi, truman, micas, veered, arriving, nam,
# Nearest to institute: samosata, nl, zero, marlboro, tennessee, hearsay, onset, ramesses,
# Nearest to bible: eject, infliction, tyrell, himself, omits, num, formalist, lynching,
# Nearest to shows: syme, cancelling, equals, postdoctoral, cartoons, nagel, atrice, mcleod,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5077 0.0828 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4917 0.0801 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4723 0.0813 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5069 0.0815 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4856 0.0800 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4993 0.0825 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4722 0.0823 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4277 0.0826 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4329 0.0825 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4222 0.0824 sec/batch
# Nearest to his: suspense, maxima, archon, fingerpicking, banknote, father, malle, dic,
# Nearest to when: negotiations, glendale, ephemeral, crevasse, hawks, crossbar, varies, tricked,
# Nearest to two: zero, six, dunn, nine, formalisms, roll, three, telephones,
# Nearest to s: mocking, info, bridgetown, dyce, uprooted, intermediary, delta, albrecht,
# Nearest to would: ancestors, functionalism, compensate, divinity, courted, uachtar, hydrozoa, garten,
# Nearest to years: tay, births, bak, total, gregorian, est, expectancy, migrant,
# Nearest to often: linking, isc, mortar, atomic, traverses, katie, bearings, usually,
# Nearest to during: erroneously, dosing, merchant, colonists, liberalize, vendetta, boarded, legalized,
# Nearest to prince: grandson, clemente, prawns, orig, executive, bush, acknowledged, physicist,
# Nearest to mainly: mellaart, trebizond, constrain, wireless, inspections, klaipeda, sobolev, tvs,
# Nearest to universe: cosmography, blowing, imparts, witty, hyperplane, mehr, syllogism, sultana,
# Nearest to heavy: organizes, palomar, getter, monopolies, politburo, szechuan, suggests, furs,
# Nearest to active: framework, detours, xvi, truman, micas, operated, monitors, veered,
# Nearest to institute: nl, samosata, zero, tennessee, hearsay, marlboro, boondocks, capoeiristas,
# Nearest to bible: translations, eject, himself, tyrell, infliction, rashi, num, misandry,
# Nearest to shows: syme, equals, postdoctoral, cartoons, cancelling, mcleod, atrice, berliners,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4228 0.0829 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4503 0.0810 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4453 0.0814 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4110 0.0812 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4401 0.0816 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4684 0.0811 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3807 0.0823 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3661 0.0806 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4287 0.0812 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3702 0.0814 sec/batch
# Nearest to his: was, suspense, archon, father, tuberculosis, maxima, malle, fingerpicking,
# Nearest to when: crevasse, glendale, negotiations, crossbar, before, awe, ephemeral, narn,
# Nearest to two: zero, six, dunn, nine, three, seven, telephones, formalisms,
# Nearest to s: info, mocking, monza, uprooted, bridgetown, dyce, albrecht, reaffirming,
# Nearest to would: functionalism, ancestors, compensate, courted, mulliken, divinity, uachtar, ngos,
# Nearest to years: tay, births, bak, total, gregorian, expectancy, older, est,
# Nearest to often: linking, isc, mortar, bearings, franchised, kiang, usually, meromorphic,
# Nearest to during: erroneously, dosing, liberalize, colonists, inspection, boarded, vendetta, merchant,
# Nearest to prince: grandson, clemente, physicist, invited, somerset, bush, orig, executive,
# Nearest to mainly: trebizond, mellaart, constrain, wireless, inspections, abandonment, roads, klaipeda,
# Nearest to universe: cosmography, blowing, imparts, syllogism, hyperplane, metafont, hyperspace, mehr,
# Nearest to heavy: organizes, palomar, getter, monopolies, furs, politburo, suggests, canopic,
# Nearest to active: framework, detours, micas, xvi, veered, operated, chrominance, monitors,
# Nearest to institute: nl, samosata, zero, tennessee, hearsay, marlboro, recognizably, capoeiristas,
# Nearest to bible: translations, rashi, eject, himself, tyrell, christianity, tiberian, infliction,
# Nearest to shows: equals, syme, cartoons, postdoctoral, atrice, mcleod, cancelling, sica,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3852 0.0829 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4236 0.0811 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3420 0.0811 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3702 0.0807 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4167 0.0814 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3869 0.0814 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4020 0.0813 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3886 0.0815 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3106 0.0808 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3408 0.0807 sec/batch
# Nearest to his: suspense, archon, father, was, maxima, sight, monophysite, nymph,
# Nearest to when: crevasse, negotiations, before, glendale, awe, crossbar, defenseless, ephemeral,
# Nearest to two: zero, six, nine, three, seven, dunn, five, telephones,
# Nearest to s: mocking, monza, dyce, info, bridgetown, reaffirming, silas, jscript,
# Nearest to would: ancestors, functionalism, courted, mulliken, compensate, ought, divinity, uachtar,
# Nearest to years: births, tay, total, expectancy, gregorian, bak, migrant, older,
# Nearest to often: linking, franchised, isc, bearings, meromorphic, usually, kiang, mortar,
# Nearest to during: erroneously, colonists, boarded, liberalize, dosing, inspection, barracks, mordor,
# Nearest to prince: grandson, clemente, invited, bush, executive, acknowledged, orig, somerset,
# Nearest to mainly: mellaart, trebizond, constrain, wireless, inspections, klaipeda, abandonment, overhaul,
# Nearest to universe: cosmography, blowing, syllogism, imparts, hyperspace, metafont, hyperplane, quantify,
# Nearest to heavy: organizes, palomar, getter, monopolies, arabidopsis, canopic, szechuan, furs,
# Nearest to active: framework, detours, micas, veered, intermediate, xvi, operated, worldliness,
# Nearest to institute: nl, samosata, zero, tennessee, hearsay, superceded, marlboro, recognizably,
# Nearest to bible: translations, rashi, tiberian, christianity, lust, tyrell, teachings, blessings,
# Nearest to shows: equals, cartoons, syme, atrice, postdoctoral, mcleod, berliners, smalltalk,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3438 0.0812 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3084 0.0815 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3554 0.0818 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3709 0.0815 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3889 0.0810 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2978 0.0814 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3225 0.0803 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3549 0.0806 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2406 0.0823 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3131 0.0816 sec/batch
# Nearest to his: suspense, archon, was, father, monophysite, dic, prelude, maxima,
# Nearest to when: before, crevasse, glendale, awe, negotiations, crossbar, ephemeral, defenseless,
# Nearest to two: zero, six, nine, three, seven, five, dunn, one,
# Nearest to s: mocking, info, dyce, albrecht, monza, bridgetown, sutherland, uprooted,
# Nearest to would: functionalism, ancestors, mulliken, compensate, courted, ought, uachtar, disaffection,
# Nearest to years: births, expectancy, tay, total, infant, migrant, gregorian, mortality,
# Nearest to often: linking, firmus, isc, kiang, franchised, neuromancer, bearings, meromorphic,
# Nearest to during: erroneously, inspection, colonists, dosing, barracks, boarded, liberalize, vendetta,
# Nearest to prince: grandson, reigned, minstrel, bush, acknowledged, clemente, executive, somerset,
# Nearest to mainly: trebizond, mellaart, wireless, constrain, inspections, klaipeda, jaffa, battleships,
# Nearest to universe: cosmography, hyperspace, syllogism, blowing, metafont, implicate, imparts, paddler,
# Nearest to heavy: organizes, palomar, getter, arabidopsis, canopic, uncompromising, szechuan, monopolies,
# Nearest to active: framework, detours, veered, xvi, truman, micas, chrominance, hillsides,
# Nearest to institute: nl, samosata, hearsay, recognizably, marlboro, superceded, tennessee, boondocks,
# Nearest to bible: translations, rashi, blessings, tiberian, tanakh, christianity, teachings, lust,
# Nearest to shows: equals, cartoons, syme, postdoctoral, atrice, mcleod, berliners, nomological,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2909 0.0829 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3060 0.0818 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3203 0.0350 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2343 0.0812 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2040 0.0816 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2180 0.0813 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2225 0.0808 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1901 0.0808 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2278 0.0825 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1621 0.0812 sec/batch
# Nearest to his: was, suspense, archon, father, prelude, younger, nymph, monophysite,
# Nearest to when: before, negotiations, glendale, crossbar, crevasse, awe, ephemeral, arrow,
# Nearest to two: zero, six, three, nine, seven, five, one, dunn,
# Nearest to s: info, dyce, mocking, bridgetown, monza, pollinators, insuring, delta,
# Nearest to would: functionalism, compensate, ancestors, mulliken, uachtar, ought, courted, to,
# Nearest to years: births, tay, gregorian, total, expectancy, older, infant, migrant,
# Nearest to often: firmus, linking, neuromancer, franchised, bearings, kiang, usually, saltwater,
# Nearest to during: colonists, inspection, erroneously, dosing, boarded, liberalize, barracks, kantele,
# Nearest to prince: grandson, acknowledged, clemente, minstrel, bush, reigned, impetus, orig,
# Nearest to mainly: trebizond, mellaart, inspections, wireless, constrain, klaipeda, jaffa, battleships,
# Nearest to universe: cosmography, hyperspace, syllogism, blowing, metafont, argumentative, implicate, magical,
# Nearest to heavy: palomar, organizes, getter, canopic, arabidopsis, uncompromising, weapons, marlon,
# Nearest to active: framework, veered, detours, operated, eurocard, volante, chrominance, truman,
# Nearest to institute: nl, samosata, superceded, marlboro, hearsay, recognizably, tennessee, postgraduate,
# Nearest to bible: translations, rashi, blessings, tanakh, tiberian, christianity, lust, genesis,
# Nearest to shows: syme, cartoons, atrice, equals, mcleod, postdoctoral, berliners, pompidou,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2109 0.0822 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2525 0.0817 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2428 0.0818 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1546 0.0806 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1997 0.0815 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2014 0.0817 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1874 0.0813 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1850 0.0820 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1957 0.0818 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1736 0.0824 sec/batch
# Nearest to his: was, suspense, archon, prelude, father, sight, monophysite, victorious,
# Nearest to when: before, crevasse, arrow, awe, crossbar, negotiations, glendale, defenseless,
# Nearest to two: zero, six, three, nine, five, seven, one, four,
# Nearest to s: dyce, bridgetown, info, mocking, monza, uprooted, stratofortress, maariv,
# Nearest to would: compensate, functionalism, ancestors, mulliken, uachtar, courted, ought, disaffection,
# Nearest to years: births, expectancy, total, tay, prevalence, migrant, infant, older,
# Nearest to often: firmus, bearings, linking, usually, neuromancer, franchised, grantham, isc,
# Nearest to during: dosing, colonists, inspection, erroneously, barracks, liberalize, boarded, mordor,
# Nearest to prince: grandson, acknowledged, orig, prawns, clemente, impetus, reigned, bush,
# Nearest to mainly: trebizond, inspections, mellaart, wireless, constrain, klaipeda, battleships, jaffa,
# Nearest to universe: cosmography, hyperspace, blowing, syllogism, metafont, argumentative, delambre, electronegativity,
# Nearest to heavy: palomar, organizes, getter, canopic, weapons, uncompromising, arabidopsis, fortified,
# Nearest to active: framework, veered, detours, truman, volante, xvi, operated, intermediate,
# Nearest to institute: nl, postgraduate, recognizably, superceded, hearsay, samosata, boondocks, marlboro,
# Nearest to bible: translations, rashi, blessings, tiberian, tanakh, num, omits, eminent,
# Nearest to shows: syme, cartoons, atrice, equals, postdoctoral, mcleod, nomological, conspicuous,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1675 0.0825 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2406 0.0814 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1804 0.0821 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1372 0.0814 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1684 0.0814 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1874 0.0815 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1972 0.0818 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1609 0.0811 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1440 0.0816 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1942 0.0811 sec/batch
# Nearest to his: was, suspense, prelude, archon, victorious, rebuke, father, poetica,
# Nearest to when: before, crevasse, crossbar, arrow, awe, glendale, quantisation, shreck,
# Nearest to two: zero, six, five, three, nine, seven, one, four,
# Nearest to s: bridgetown, dyce, mocking, info, maariv, monza, emmitt, uprooted,
# Nearest to would: functionalism, compensate, ancestors, mulliken, courted, uachtar, ought, reconnection,
# Nearest to years: births, expectancy, tay, older, infant, total, migrant, gregorian,
# Nearest to often: firmus, neuromancer, franchised, linking, bearings, usually, contest, algebraically,
# Nearest to during: dosing, colonists, barracks, inspection, liberalize, erroneously, mordor, stayed,
# Nearest to prince: grandson, reigned, acknowledged, impetus, monarch, minstrel, clemente, mirror,
# Nearest to mainly: trebizond, inspections, mellaart, wireless, klaipeda, constrain, battleships, jaffa,
# Nearest to universe: cosmography, hyperspace, metafont, syllogism, magical, electronegativity, blowing, argumentative,
# Nearest to heavy: palomar, canopic, getter, organizes, arabidopsis, fortified, uncompromising, furs,
# Nearest to active: veered, framework, detours, xvi, volante, truman, intermediate, operated,
# Nearest to institute: nl, postgraduate, recognizably, superceded, samosata, hearsay, boondocks, tennessee,
# Nearest to bible: translations, rashi, blessings, tiberian, tanakh, eminent, omits, num,
# Nearest to shows: syme, cartoons, atrice, equals, mcleod, postdoctoral, scanlines, performing,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1849 0.0823 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1926 0.0821 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1905 0.0807 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1813 0.0811 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1634 0.0827 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1387 0.0816 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1825 0.0824 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1432 0.0828 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1728 0.0813 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2101 0.0795 sec/batch
# Nearest to his: was, suspense, himself, archon, sight, prelude, lucien, doo,
# Nearest to when: before, negotiations, awe, glendale, defenseless, arrow, crossbar, crevasse,
# Nearest to two: zero, six, three, nine, five, one, seven, four,
# Nearest to s: relations, dyce, bridgetown, mocking, silas, insuring, emmitt, info,
# Nearest to would: mulliken, ancestors, courted, compensate, functionalism, uachtar, disaffection, ought,
# Nearest to years: births, expectancy, infant, migrant, tay, older, total, gregorian,
# Nearest to often: firmus, neuromancer, franchised, contest, grantham, linking, bearings, usually,
# Nearest to during: barracks, dosing, colonists, liberalize, inspection, boarded, stayed, erroneously,
# Nearest to prince: grandson, reigned, acknowledged, minstrel, monarch, impetus, princes, invited,
# Nearest to mainly: trebizond, mellaart, inspections, wireless, klaipeda, jaffa, sourcebook, constrain,
# Nearest to universe: cosmography, hyperspace, syllogism, metafont, magical, delambre, blowing, electronegativity,
# Nearest to heavy: palomar, organizes, canopic, arabidopsis, getter, furs, uncompromising, fortified,
# Nearest to active: veered, framework, detours, xvi, truman, worldliness, volante, intermediate,
# Nearest to institute: postgraduate, nl, hearsay, recognizably, samosata, superceded, sciences, boondocks,
# Nearest to bible: rashi, translations, blessings, tiberian, tanakh, omits, untrustworthy, archaeology,
# Nearest to shows: syme, atrice, cartoons, equals, postdoctoral, mcleod, chicks, performing,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2467 0.0827 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1312 0.0819 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1258 0.0818 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1397 0.0812 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0386 0.0818 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1371 0.0815 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1238 0.0815 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1591 0.0823 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1649 0.0113 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1322 0.0819 sec/batch
# Nearest to his: was, suspense, himself, archon, sight, brotherly, prelude, still,
# Nearest to when: before, awe, arrow, crossbar, quantisation, negotiations, crevasse, defenseless,
# Nearest to two: zero, six, three, five, nine, seven, one, four,
# Nearest to s: relations, dyce, mocking, info, stratofortress, bridgetown, insuring, emmitt,
# Nearest to would: mulliken, compensate, ancestors, courted, functionalism, ought, uachtar, disaffection,
# Nearest to years: births, infant, expectancy, migrant, total, tay, older, gregorian,
# Nearest to often: firmus, neuromancer, franchised, bearings, linking, algebraically, usually, meromorphic,
# Nearest to during: dosing, colonists, inspection, barracks, erroneously, mordor, liberalize, stayed,
# Nearest to prince: grandson, acknowledged, minstrel, reigned, impetus, executive, monarch, colette,
# Nearest to mainly: trebizond, inspections, mellaart, wireless, sourcebook, klaipeda, jaffa, hamon,
# Nearest to universe: cosmography, hyperspace, syllogism, metafont, delambre, electronegativity, structuralism, paddler,
# Nearest to heavy: palomar, uncompromising, canopic, arabidopsis, organizes, getter, marlon, fortified,
# Nearest to active: veered, framework, detours, xvi, volante, truman, intermediate, worldliness,
# Nearest to institute: postgraduate, sciences, nl, archaeological, hearsay, stanford, recognizably, graduate,
# Nearest to bible: rashi, translations, blessings, tanakh, tiberian, untrustworthy, omits, sahib,
# Nearest to shows: cartoons, syme, atrice, equals, performing, mcleod, chicks, scanlines,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0852 0.0824 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0615 0.0806 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1157 0.0809 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0503 0.0808 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0571 0.0821 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0429 0.0809 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1038 0.0813 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1005 0.0815 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1002 0.0811 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0297 0.0810 sec/batch
# Nearest to his: was, suspense, prelude, himself, archon, perpetuated, victorious, doo,
# Nearest to when: before, awe, arrow, negotiations, crossbar, quantisation, crevasse, auteurism,
# Nearest to two: zero, six, three, five, nine, seven, one, four,
# Nearest to s: relations, dyce, bridgetown, info, mocking, monza, emmitt, delta,
# Nearest to would: mulliken, compensate, ancestors, courted, uachtar, functionalism, disaffection, ought,
# Nearest to years: births, expectancy, infant, migrant, older, total, tay, rate,
# Nearest to often: firmus, franchised, usually, neuromancer, algebraically, linking, bearings, meromorphic,
# Nearest to during: dosing, colonists, inspection, erroneously, mordor, barracks, liberalize, stayed,
# Nearest to prince: grandson, acknowledged, impetus, minstrel, monarch, reigned, invited, executive,
# Nearest to mainly: mellaart, trebizond, inspections, wireless, hamon, sourcebook, optionally, jaffa,
# Nearest to universe: cosmography, hyperspace, syllogism, electronegativity, metafont, blowing, incandescent, toppling,
# Nearest to heavy: palomar, uncompromising, arabidopsis, canopic, marlon, organizes, getter, furs,
# Nearest to active: veered, framework, detours, truman, volante, xvi, intermediate, monitors,
# Nearest to institute: postgraduate, sciences, nl, archaeological, stanford, recognizably, superceded, uc,
# Nearest to bible: rashi, translations, blessings, omits, untrustworthy, tiberian, jastrow, genesis,
# Nearest to shows: syme, cartoons, atrice, equals, mcleod, performing, chicks, witnessed,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0452 0.0830 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0391 0.0818 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0420 0.0808 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0655 0.0820 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0896 0.0810 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0671 0.0813 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0609 0.0810 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1078 0.0801 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0649 0.0813 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0468 0.0819 sec/batch
# Nearest to his: was, suspense, prelude, sight, victorious, himself, doo, perpetuated,
# Nearest to when: before, arrow, quantisation, awe, crossbar, crevasse, auteurism, negotiations,
# Nearest to two: zero, six, three, five, nine, seven, one, four,
# Nearest to s: relations, delta, dyce, info, brinton, stratofortress, jscript, emmitt,
# Nearest to would: mulliken, compensate, ancestors, functionalism, antisymmetric, shampoo, courted, reconnection,
# Nearest to years: births, expectancy, infant, migrant, older, tay, total, four,
# Nearest to often: firmus, neuromancer, algebraically, franchised, usually, meromorphic, bearings, gels,
# Nearest to during: dosing, colonists, barracks, inspection, erroneously, mordor, stayed, liberalize,
# Nearest to prince: grandson, acknowledged, monarch, minstrel, impetus, reigned, pavement, nx,
# Nearest to mainly: trebizond, mellaart, inspections, wireless, optionally, hamon, battleships, condoms,
# Nearest to universe: hyperspace, cosmography, metafont, syllogism, toppling, incandescent, electronegativity, magical,
# Nearest to heavy: palomar, uncompromising, arabidopsis, getter, organizes, canopic, marlon, furs,
# Nearest to active: veered, volante, truman, framework, xvi, intermediate, binding, detours,
# Nearest to institute: postgraduate, sciences, nl, graduate, archaeological, stanford, superceded, uc,
# Nearest to bible: rashi, translations, blessings, omits, untrustworthy, jastrow, tiberian, eminent,
# Nearest to shows: cartoons, syme, atrice, equals, performing, scanlines, mcleod, actresses,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0587 0.0823 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0790 0.0816 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0544 0.0820 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0243 0.0821 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0662 0.0818 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0269 0.0812 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0500 0.0812 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0626 0.0817 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0856 0.0808 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0835 0.0814 sec/batch
# Nearest to his: was, suspense, prelude, he, sight, himself, still, had,
# Nearest to when: before, awe, arrow, quantisation, negotiations, defenseless, crossbar, auteurism,
# Nearest to two: zero, six, three, nine, five, seven, one, four,
# Nearest to s: relations, bridgetown, dyce, zero, zeal, emmitt, following, brinton,
# Nearest to would: mulliken, ancestors, compensate, courted, uachtar, disaffection, ought, functionalism,
# Nearest to years: births, infant, older, expectancy, gregorian, tay, migrant, four,
# Nearest to often: firmus, neuromancer, usually, algebraically, franchised, aasen, grantham, bearings,
# Nearest to during: dosing, colonists, barracks, liberalize, stayed, chechen, mordor, disarray,
# Nearest to prince: grandson, monarch, impetus, reigned, acknowledged, minstrel, residenz, executive,
# Nearest to mainly: trebizond, inspections, mellaart, sourcebook, hamon, optionally, condoms, battleships,
# Nearest to universe: hyperspace, cosmography, toppling, metafont, syllogism, delambre, magical, blowing,
# Nearest to heavy: palomar, uncompromising, organizes, marlon, arabidopsis, canopic, getter, furs,
# Nearest to active: veered, intermediate, volante, binding, xvi, framework, detours, truman,
# Nearest to institute: postgraduate, sciences, archaeological, nl, graduate, stanford, superceded, uc,
# Nearest to bible: rashi, translations, blessings, omits, tiberian, untrustworthy, genesis, jastrow,
# Nearest to shows: cartoons, syme, performing, atrice, actresses, equals, petered, mcleod,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0424 0.0830 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0146 0.0817 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0312 0.0815 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0836 0.0816 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0414 0.0818 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1227 0.0826 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1435 0.0815 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0620 0.0816 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0275 0.0813 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0540 0.0801 sec/batch
# Nearest to his: was, he, suspense, himself, had, prelude, father, sight,
# Nearest to when: before, awe, arrow, quantisation, auteurism, shreck, negotiations, defenseless,
# Nearest to two: zero, six, three, seven, nine, five, one, four,
# Nearest to s: relations, following, dyce, emmitt, bridgetown, zero, zeal, brinton,
# Nearest to would: mulliken, ancestors, compensate, courted, ought, was, reconnection, disaffection,
# Nearest to years: births, infant, expectancy, older, migrant, rate, gregorian, tay,
# Nearest to often: firmus, algebraically, neuromancer, usually, franchised, grantham, bearings, immaterial,
# Nearest to during: dosing, colonists, barracks, inspection, erroneously, stayed, liberalize, mordor,
# Nearest to prince: monarch, reigned, grandson, acknowledged, executive, impetus, minstrel, residenz,
# Nearest to mainly: trebizond, inspections, sourcebook, mellaart, jaffa, optionally, klaipeda, hamon,
# Nearest to universe: hyperspace, cosmography, syllogism, synchronize, metafont, toppling, electronegativity, creationism,
# Nearest to heavy: palomar, uncompromising, organizes, marlon, canopic, arabidopsis, furs, getter,
# Nearest to active: veered, binding, volante, xvi, intermediate, truman, worldliness, detours,
# Nearest to institute: postgraduate, sciences, archaeological, nl, graduate, stanford, boondocks, marlboro,
# Nearest to bible: rashi, translations, blessings, omits, tiberian, untrustworthy, genesis, jastrow,
# Nearest to shows: performing, cartoons, syme, actresses, atrice, equals, chicks, mcleod,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0078 0.0812 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9949 0.0816 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0598 0.0814 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0144 0.0808 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0795 0.0819 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0438 0.0689 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0059 0.0813 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0020 0.0814 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0096 0.0810 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9729 0.0799 sec/batch
# Nearest to his: was, he, himself, had, father, prelude, suspense, friend,
# Nearest to when: before, awe, quantisation, arrow, auteurism, crossbar, shreck, negotiations,
# Nearest to two: zero, six, three, one, five, seven, nine, four,
# Nearest to s: zero, wandered, bridgetown, emmitt, mocking, dyce, delta, following,
# Nearest to would: mulliken, ancestors, compensate, newtonian, reconnection, courted, was, could,
# Nearest to years: births, infant, expectancy, older, migrant, rate, gregorian, four,
# Nearest to often: firmus, neuromancer, algebraically, franchised, usually, grantham, evidenced, bearings,
# Nearest to during: dosing, colonists, inspection, barracks, erroneously, stayed, liberalize, karlovac,
# Nearest to prince: monarch, reigned, grandson, acknowledged, impetus, executive, pavement, residenz,
# Nearest to mainly: sourcebook, inspections, mellaart, optionally, hamon, trebizond, jahan, wireless,
# Nearest to universe: hyperspace, cosmography, toppling, magical, metafont, syllogism, creationism, synchronize,
# Nearest to heavy: palomar, marlon, uncompromising, organizes, arabidopsis, canopic, getter, ionic,
# Nearest to active: veered, binding, volante, intermediate, xvi, monitors, truman, intergovernmentalism,
# Nearest to institute: postgraduate, archaeological, nl, sciences, marlboro, hearsay, thought, stanford,
# Nearest to bible: rashi, translations, blessings, omits, tiberian, untrustworthy, genesis, jastrow,
# Nearest to shows: performing, cartoons, actresses, atrice, syme, equals, tv, witnessed,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9939 0.0814 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9347 0.0802 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0176 0.0806 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0030 0.0815 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9942 0.0805 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0354 0.0810 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8761 0.0802 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9811 0.0795 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9374 0.0805 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9708 0.0805 sec/batch
# Nearest to his: was, he, had, suspense, himself, father, prelude, graduating,
# Nearest to when: before, arrow, quantisation, awe, auteurism, crossbar, shreck, infractions,
# Nearest to two: zero, six, three, five, one, seven, four, nine,
# Nearest to s: delta, zero, bridgetown, following, wandered, emmitt, cabinda, brinton,
# Nearest to would: compensate, ancestors, mulliken, newtonian, shampoo, to, reconnection, courted,
# Nearest to years: births, infant, expectancy, older, migrant, rate, four, total,
# Nearest to often: firmus, neuromancer, usually, algebraically, franchised, grantham, saltwater, gels,
# Nearest to during: dosing, colonists, barracks, inspection, stayed, liberalize, erroneously, chechen,
# Nearest to prince: monarch, grandson, reigned, nx, acknowledged, minstrel, pavement, residenz,
# Nearest to mainly: inspections, trebizond, mellaart, optionally, sourcebook, klaipeda, jahan, hamon,
# Nearest to universe: hyperspace, cosmography, toppling, electronegativity, syllogism, creationism, magical, metafont,
# Nearest to heavy: palomar, uncompromising, marlon, organizes, furs, arabidopsis, canopic, meteoric,
# Nearest to active: veered, volante, monitors, intermediate, binding, truman, xvi, intergovernmentalism,
# Nearest to institute: postgraduate, archaeological, sciences, nl, marlboro, stanford, geneticist, uc,
# Nearest to bible: rashi, translations, blessings, omits, tiberian, jastrow, untrustworthy, didache,
# Nearest to shows: performing, actresses, syme, atrice, tv, cartoons, mcleod, equals,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9929 0.0824 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9863 0.0807 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9623 0.0808 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0136 0.0803 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0094 0.0793 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9761 0.0812 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0053 0.0804 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9973 0.0800 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9733 0.0805 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9823 0.0804 sec/batch
# Nearest to his: was, he, himself, had, prelude, father, suspense, still,
# Nearest to when: before, quantisation, shreck, auteurism, infractions, awe, arrow, adipose,
# Nearest to two: zero, six, three, nine, five, seven, one, four,
# Nearest to s: zero, emmitt, brinton, following, relations, eight, stratofortress, insuring,
# Nearest to would: ancestors, mulliken, compensate, courted, antisymmetric, uncreated, newtonian, to,
# Nearest to years: births, infant, expectancy, older, migrant, rate, four, gregorian,
# Nearest to often: firmus, neuromancer, algebraically, usually, grantham, franchised, evidenced, saltwater,
# Nearest to during: dosing, colonists, barracks, stayed, debbie, erroneously, clipperton, lima,
# Nearest to prince: monarch, reigned, grandson, residenz, acknowledged, nx, alcibiades, pavement,
# Nearest to mainly: inspections, mellaart, optionally, sourcebook, trebizond, hamon, jahan, klaipeda,
# Nearest to universe: hyperspace, cosmography, toppling, creationism, electronegativity, incandescent, metafont, rosser,
# Nearest to heavy: uncompromising, palomar, marlon, organizes, arabidopsis, furs, canopic, scandinavians,
# Nearest to active: veered, volante, binding, monitors, intergovernmentalism, truman, intermediate, xvi,
# Nearest to institute: postgraduate, archaeological, marlboro, sciences, nl, geneticist, boondocks, uc,
# Nearest to bible: rashi, translations, blessings, omits, tiberian, jastrow, untrustworthy, num,
# Nearest to shows: performing, actresses, cartoons, syme, tv, atrice, equals, favor,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9968 0.0813 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0096 0.0798 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0035 0.0805 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0139 0.0798 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0045 0.0804 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9911 0.0810 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9876 0.0812 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9415 0.0806 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9807 0.0806 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0375 0.0801 sec/batch
# Nearest to his: was, he, himself, father, had, still, prelude, friend,
# Nearest to when: before, quantisation, auteurism, infractions, awe, shreck, arrow, shortened,
# Nearest to two: zero, six, three, five, one, seven, nine, four,
# Nearest to s: relations, brinton, following, zero, credible, insuring, dyce, wandered,
# Nearest to would: mulliken, ancestors, compensate, courted, antisymmetric, to, was, newtonian,
# Nearest to years: births, older, infant, expectancy, four, rate, migrant, gregorian,
# Nearest to often: firmus, neuromancer, algebraically, grantham, usually, franchised, evidenced, bearings,
# Nearest to during: dosing, colonists, stayed, barracks, inspection, debbie, turmoil, karlovac,
# ...
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9080 0.0801 sec/batch
# Nearest to his: he, himself, was, had, him, at, father, poissy,
# Nearest to when: before, to, after, quantisation, then, shreck, disclaimed, blinds,
# Nearest to two: three, zero, six, four, one, five, seven, nine,
# Nearest to s: zero, in, eight, of, an, and, a, with,
# Nearest to would: was, could, it, until, to, icbms, ofc, fool,
# Nearest to years: four, older, two, expectancy, births, infant, over, age,
# Nearest to often: usually, typically, generally, or, also, range, are, most,
# Nearest to during: dosing, stayed, january, early, repo, carotid, rims, clipperton,
# Nearest to prince: monarch, dorset, yao, incurring, mirror, barristers, trapping, pavement,
# Nearest to mainly: sourcebook, besan, food, hamon, klaipeda, inspections, kaolin, mellaart,
# Nearest to universe: hyperspace, creationism, gamow, cosmography, toppling, intensities, kazantzakis, chinguetti,
# Nearest to heavy: marlon, uncompromising, quadrant, palomar, organizes, engaged, cover, ionic,
# Nearest to active: monitors, volante, macrophages, chieftain, quebec, binding, intrusion, amusing,
# Nearest to institute: archaeological, nl, apologetics, gernika, national, marlboro, postgraduate, kuro,
# Nearest to bible: rashi, blessings, omits, gpl, untrustworthy, tiberian, translations, edie,
# Nearest to shows: actresses, tv, performing, superficially, terrestrial, show, granada, wholesalers,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8291 0.0818 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8438 0.0806 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8445 0.0808 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8422 0.0810 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8673 0.0812 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8841 0.0803 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8392 0.0805 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8622 0.0811 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9131 0.0815 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8630 0.0807 sec/batch
# Nearest to his: he, was, himself, poissy, had, father, work, at,
# Nearest to when: before, quantisation, to, after, auteurism, wchl, disclaimed, hes,
# Nearest to two: zero, three, six, one, four, five, seven, nine,
# Nearest to s: zero, of, in, eight, a, with, an, two,
# Nearest to would: was, could, to, until, it, be, were, three,
# Nearest to years: four, two, expectancy, five, infant, births, older, zero,
# Nearest to often: usually, typically, generally, firmus, also, are, or, most,
# Nearest to during: dosing, early, stayed, repo, january, carotid, of, rims,
# Nearest to prince: monarch, dorset, reigned, yao, incurring, acad, venerated, mirror,
# Nearest to mainly: sourcebook, food, klaipeda, kaolin, besan, hamon, inspections, holly,
# Nearest to universe: hyperspace, creationism, gamow, cosmography, kazantzakis, toppling, realities, intensities,
# Nearest to heavy: quadrant, palomar, marlon, organizes, uncompromising, cover, ranging, kwahu,
# Nearest to active: monitors, macrophages, volante, chieftain, quebec, intrusion, binding, amusing,
# Nearest to institute: archaeological, gernika, nl, marlboro, apologetics, kuro, postgraduate, academy,
# Nearest to bible: rashi, blessings, gpl, omits, untrustworthy, genesis, translations, tiberian,
# Nearest to shows: actresses, tv, performing, terrestrial, superficially, show, andromeda, wholesalers,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8549 0.0821 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8514 0.0812 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8308 0.0801 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8361 0.0805 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8932 0.0812 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8453 0.0808 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9476 0.0807 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9176 0.0800 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8908 0.0802 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8336 0.0806 sec/batch
# Nearest to his: he, was, himself, had, work, friend, father, spent,
# Nearest to when: before, after, disclaimed, to, wchl, auteurism, quantisation, then,
# Nearest to two: zero, three, six, one, four, five, seven, nine,
# Nearest to s: zero, of, in, and, with, a, the, two,
# Nearest to would: was, could, to, until, that, it, be, were,
# Nearest to years: four, expectancy, two, zero, births, infant, one, five,
# Nearest to often: usually, typically, generally, or, are, firmus, neuromancer, most,
# Nearest to during: dosing, early, january, stayed, repo, of, on, and,
# Nearest to prince: monarch, dorset, yao, acad, incurring, mirror, safi, barristers,
# Nearest to mainly: sourcebook, towards, followed, holly, klaipeda, besan, inspections, hamon,
# Nearest to universe: hyperspace, creationism, cosmography, kazantzakis, gamow, realities, chinguetti, toppling,
# Nearest to heavy: marlon, palomar, organizes, uncompromising, quadrant, cover, kwahu, ranging,
# Nearest to active: volante, monitors, macrophages, intrusion, amusing, chieftain, binding, quebec,
# Nearest to institute: archaeological, gernika, nl, apologetics, marlboro, kuro, calif, ramesses,
# Nearest to bible: rashi, gpl, blessings, omits, untrustworthy, genesis, translations, authorised,
# Nearest to shows: actresses, performing, superficially, tv, show, terrestrial, benghazi, andromeda,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7793 0.0819 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8700 0.0796 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7947 0.0799 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8531 0.0811 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8551 0.0802 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8524 0.0808 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9071 0.0320 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8155 0.0808 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8466 0.0808 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8202 0.0803 sec/batch
# Nearest to his: he, was, himself, had, father, friend, him, at,
# Nearest to when: before, after, to, and, until, disclaimed, a, quantisation,
# Nearest to two: zero, three, six, one, four, five, seven, nine,
# Nearest to s: zero, of, a, eight, in, an, and, by,
# Nearest to would: could, was, it, to, until, be, icbms, announce,
# Nearest to years: expectancy, four, older, two, births, infant, over, age,
# Nearest to often: usually, typically, generally, are, firmus, most, or, neuromancer,
# Nearest to during: dosing, early, repo, january, of, stayed, on, dominatrices,
# Nearest to prince: monarch, dorset, yao, safi, alcibiades, acad, incurring, executive,
# Nearest to mainly: sourcebook, besan, followed, inspections, klaipeda, hamon, kaolin, conservative,
# Nearest to universe: hyperspace, creationism, kazantzakis, cosmography, realities, gamow, supernatural, chinguetti,
# Nearest to heavy: marlon, uncompromising, palomar, organizes, quadrant, cover, engaged, ionic,
# Nearest to active: volante, monitors, chieftain, intrusion, macrophages, amusing, quebec, binding,
# Nearest to institute: archaeological, gernika, nl, apologetics, marlboro, ramesses, kuro, calif,
# Nearest to bible: rashi, blessings, gpl, omits, untrustworthy, translations, authorised, tiberian,
# Nearest to shows: actresses, tv, performing, show, superficially, terrestrial, benghazi, presenting,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8711 0.0815 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8336 0.0798 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8200 0.0810 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7633 0.0810 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8359 0.0804 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8670 0.0810 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8892 0.0801 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7484 0.0811 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7761 0.0802 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8269 0.0809 sec/batch
# Nearest to his: he, was, himself, had, spent, him, friend, father,
# Nearest to when: before, to, after, and, a, then, from, quantisation,
# Nearest to two: three, zero, six, four, one, seven, five, nine,
# Nearest to s: of, zero, in, an, a, with, eight, and,
# Nearest to would: was, could, it, to, that, be, not, were,
# Nearest to years: expectancy, four, births, older, two, over, infant, zero,
# Nearest to often: usually, typically, generally, are, or, most, called, firmus,
# Nearest to during: dosing, early, january, stayed, repo, and, on, carotid,
# Nearest to prince: monarch, dorset, yao, incurring, nx, mirror, acad, safi,
# Nearest to mainly: sourcebook, klaipeda, besan, kaolin, towards, inspections, difficulty, mandaeans,
# Nearest to universe: hyperspace, creationism, kazantzakis, gamow, isotropy, cosmography, abreast, chinguetti,
# Nearest to heavy: marlon, uncompromising, palomar, quadrant, organizes, cover, engaged, ionic,
# Nearest to active: monitors, volante, intrusion, chieftain, amusing, macrophages, quebec, binding,
# Nearest to institute: archaeological, gernika, nl, apologetics, calif, marlboro, kuro, ramesses,
# Nearest to bible: rashi, omits, gpl, authorised, blessings, untrustworthy, translations, biblical,
# Nearest to shows: actresses, performing, show, tv, superficially, terrestrial, benghazi, presenting,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7677 0.0810 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8041 0.0808 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8521 0.0816 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8158 0.0813 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8186 0.0806 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8773 0.0803 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8471 0.0800 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8180 0.0809 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8130 0.0818 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8558 0.0809 sec/batch
# Nearest to his: he, was, himself, father, had, spent, at, died,
# Nearest to when: before, to, after, until, then, a, shreck, wchl,
# Nearest to two: three, zero, six, four, one, seven, nine, five,
# Nearest to s: zero, of, by, in, a, eight, one, an,
# Nearest to would: could, was, until, it, ofc, were, be, to,
# Nearest to years: four, expectancy, older, two, zero, five, births, infant,
# Nearest to often: usually, typically, generally, or, called, interpreted, most, firmus,
# Nearest to during: dosing, early, stayed, january, dominatrices, on, carotid, repo,
# Nearest to prince: monarch, yao, dorset, acad, alcibiades, nx, mirror, son,
# Nearest to mainly: sourcebook, klaipeda, kaolin, difficulty, inspections, mandaeans, holly, conservative,
# Nearest to universe: hyperspace, creationism, gamow, kazantzakis, supernatural, cosmography, abreast, chinguetti,
# Nearest to heavy: marlon, palomar, organizes, quadrant, uncompromising, cover, engaged, ionic,
# Nearest to active: chieftain, volante, macrophages, binding, amusing, monitors, quebec, intrusion,
# Nearest to institute: archaeological, nl, gernika, national, politecnico, calif, apologetics, ramesses,
# Nearest to bible: rashi, gpl, omits, blessings, untrustworthy, authorised, translations, vermes,
# Nearest to shows: actresses, performing, show, tv, presenting, terrestrial, superficially, wholesalers,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8928 0.0812 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8269 0.0812 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8247 0.0808 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8699 0.0805 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8322 0.0812 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8455 0.0808 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8283 0.0804 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8569 0.0808 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7982 0.0810 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8263 0.0821 sec/batch
# Nearest to his: he, himself, was, father, had, him, spent, work,
# Nearest to when: before, to, after, the, until, and, a, from,
# Nearest to two: three, zero, six, one, four, five, nine, seven,
# Nearest to s: of, zero, in, an, and, a, with, by,
# Nearest to would: could, was, it, be, until, to, that, were,
# Nearest to years: four, expectancy, two, zero, five, infant, over, older,
# Nearest to often: usually, typically, generally, most, called, are, or, also,
# Nearest to during: dosing, early, on, and, the, repo, in, january,
# Nearest to prince: monarch, acad, dorset, yao, mirror, safi, nx, alcibiades,
# Nearest to mainly: sourcebook, klaipeda, followed, holly, towards, inspections, food, difficulty,
# Nearest to universe: hyperspace, creationism, kazantzakis, abreast, cosmography, gamow, supernatural, realities,
# Nearest to heavy: organizes, marlon, palomar, quadrant, uncompromising, ionic, cover, extreme,
# Nearest to active: macrophages, amusing, binding, volante, monitors, chieftain, quebec, intrusion,
# Nearest to institute: archaeological, gernika, nl, apologetics, calif, politecnico, ramesses, marlboro,
# Nearest to bible: rashi, gpl, omits, untrustworthy, blessings, authorised, genesis, translations,
# Nearest to shows: tv, actresses, show, performing, terrestrial, superficially, wholesalers, andromeda,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8432 0.0818 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8455 0.0815 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9168 0.0810 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9444 0.0809 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8760 0.0811 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8444 0.0812 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8046 0.0814 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8257 0.0808 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7390 0.0813 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8618 0.0808 sec/batch
# Nearest to his: he, himself, was, spent, work, him, friend, father,
# Nearest to when: before, to, after, disclaimed, and, until, can, from,
# Nearest to two: zero, three, one, six, four, five, nine, seven,
# Nearest to s: zero, of, in, the, a, and, an, two,
# Nearest to would: could, was, until, were, be, it, that, to,
# Nearest to years: four, expectancy, five, two, zero, infant, rate, births,
# Nearest to often: usually, typically, generally, most, as, are, also, called,
# Nearest to during: dosing, early, on, january, repo, and, in, of,
# Nearest to prince: monarch, acad, dorset, yao, mirror, safi, ttt, nx,
# Nearest to mainly: sourcebook, followed, klaipeda, inspections, towards, holly, kaolin, conservative,
# Nearest to universe: hyperspace, creationism, supernatural, kazantzakis, cosmography, abreast, realities, gamow,
# Nearest to heavy: marlon, uncompromising, palomar, quadrant, organizes, cover, ionic, engaged,
# Nearest to active: amusing, macrophages, chieftain, binding, quebec, volante, monitors, intrusion,
# Nearest to institute: gernika, archaeological, apologetics, nl, calif, politecnico, ramesses, marlboro,
# Nearest to bible: rashi, gpl, omits, blessings, untrustworthy, genesis, authorised, tiberian,
# Nearest to shows: tv, show, performing, actresses, terrestrial, andromeda, wholesalers, superficially,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8510 0.0818 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8275 0.0805 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
